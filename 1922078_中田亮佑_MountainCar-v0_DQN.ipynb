# %% [markdown]
# # 基本は`DQN-CartPole.ipynb`と同じ、あとはPyTorchの公式サイトを見て理解を深めた
# ## 報酬のところを少しCartPoleとは変えある

# %%
import random
from collections import namedtuple
from itertools import count
import math
import time

import gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

np.random.seed(1)

# %%
# 学習に使う変数を整理
ENV = 'MountainCar-v0'
# 報酬割引率
GAMMA = 0.9
# 1試行（1エピソード）の最大ステップ数
MAX_STEP = 200
# 最大試行回数（エピソード数）
NUM_EPISODES = 10000
# バッチサイズ32
BATCH_SIZE = 32
# キャパ
CAPACITY = 10000

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def save_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)

    anim.save('MountainCar-v0.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
# エージェントが行う行動を与えられた状態によって判断する部分（深層強化学習（DQN）を行う部分）
class Brain:

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        self.memory = ReplayMemory(CAPACITY)
        # ニューラルネットワーク
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, num_actions))

        print(self.model)
        # 最適化手法
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)

    # 結合パラメータを学習する部分
    def replay(self):

        # 最初にメモリサイズを確認する
        # 指定したバッチサイズより小さい場合は何もしない
        if len(self.memory) < BATCH_SIZE:
            return
        # ミニバッチ用のデータを取得（ランダム）
        transitions = self.memory.sample(BATCH_SIZE)
        # transitions は (state, action, next_state, reward) * BATCH_SIZE
        # (state * BATCH_SIZE, action * BATCH_SIZE, next_state * BATCH_SIZE, reward * BATCH_SIZE)
        batch = Transition(*zip(*transitions))

        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        # 教師信号となるQ(s_t, a_t)を求める
        # モデルを推論モードに
        self.model.eval()
        # self.model(state_batch)は，2つのQ値を出力する
        # [torch.FloatTensor of size BATCH_SIZE * 2]になってるので
        # 実行したアクション（a_t）に対応するQ値をaction_batchで行った行動a_tのindexを使って取得する
        state_action_values = self.model(state_batch).gather(1, action_batch)
        # CartPole がdoneになっていない，かつ，next_stateがあるかをチェックするためのマスクを作成
        # non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))
        non_final_mask = torch.BoolTensor(tuple(map(lambda s: s is not None, batch.next_state)))
        # maxQ(s_t+1, a)を求める
        next_state_values = torch.zeros(BATCH_SIZE)
        # 次の状態があるindexの最大Q値を求める
        next_state_values[non_final_mask] = self.model(non_final_next_states).max(1)[0].detach()
        # Q学習の行動価値関数更新式からQ(S_t, a_t)を求める
        expected_state_action_values = reward_batch + GAMMA * next_state_values
        # モデルを訓練モードに切り替え
        self.model.train()
        # 二乗誤差の代わりにHuber関数を使う
        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        # 勾配をリセット
        self.optimizer.zero_grad()
        # 誤差逆伝搬
        loss.backward()
        # ニューラルネットワークの重み更新
        self.optimizer.step()

    # 現在の状態に応じて行動を決定する
    def decide_action(self, state, episode):
        # ε-greedy法で徐々に最適行動を採用するようにする
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            # 推論モードに
            self.model.eval()
            # ネットワークの出力の最大値のindexを取得
            # view関数で行列サイズを（1 * 1）に調整
            with torch.no_grad():
                action = self.model(state).max(1)[1].view(1, 1)

        else:
            # 右，左ランダムに行動する
            # actionは[torch.LongTensor of size 1 * 1]
            action = torch.LongTensor([[random.randrange(self.num_actions)]])

        return action

# %%
# エージェントクラス
class Agent:
    def __init__(self, num_states, num_actions):
        # Brainクラスをインスタンス化
        self.brain = Brain(num_states, num_actions)
    # Q関数の更新
    def update_q_function(self):
        self.brain.replay()
    # アクションを決定する
    def get_action(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action
    # 状態を保存
    def memorize(self, state, action, next_state, reward):
        self.brain.memory.push(state, action, next_state, reward)

# %%
# CartPoleを実行する環境クラス
class Environment:

    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n
        self.agent = Agent(num_states, num_actions)

    def run(self):

        episode_10_list = np.zeros(10) # 10試行分の立ち続けた平均ステップ数の出力に使う
        complete_episodes = 0  # 旗まで連続して到達した数
        is_episode_final = False  # 最終試行フラグ
        frames = []  # 動画用に画像を格納する変数
        before = time.time()

        # 全エピソードループ
        for episode in range(NUM_EPISODES):
            # エピソード毎に環境を初期化
            observation = self.env.reset()
            state = observation
            # numpyからpytorchのテンソルに変換
            state = torch.from_numpy(state).type(torch.FloatTensor)
            # size を 1*4 に変換
            state = torch.unsqueeze(state, 0)
            rewards = 0

            for step in range(MAX_STEP):
                # 最終試行はframesに画像を追加しておく
                if is_episode_final:
                    frames.append(self.env.render(mode='rgb_array'))
                # 最初の行動を決める
                action = self.agent.get_action(state, episode)
                # 最初の行動から次の状態を求める
                observation_next, _, done, _ = self.env.step(action.item())
                # 報酬を与える
                if done:
                    # 次の状態はないのでNoneを代入
                    state_next = None
                    # 直前10エピソードで立てた平均ステップ数を格納
                    episode_10_list = np.hstack((episode_10_list[1:], step+1))
                    if step < 199:
                        # 規定回数までに到達できたら+200 ←特に深い理由はない(見栄えの問題)
                        reward = torch.FloatTensor([0])
                        # 連続成功回数を+1
                        complete_episodes += 1
                    else:
                        # 立ったまま終了した場合は報酬-1
                        reward = torch.FloatTensor([-1.0])
                        rewards += -1
                        # 連続成功回数をリセット
                        complete_episodes = 0
                else:
                    # 途中の報酬は-1
                    rewards += -1
                    reward = torch.FloatTensor([-1.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)

                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)
                # Q関数をニューラルネットで更新
                self.agent.update_q_function()
                # 状態を次の状態に更新
                state = state_next
                # エピソード終了時
                if done:
                    print('{0}エピソード: {1}ステップで終了 - rewards: {2}'.format(episode, step, rewards))
                    break

            # 最終エピソードの場合は動画を保存
            if is_episode_final:
                save_as_gif(frames)
                break
            # 10回連続で成功したら、次のエピソードで終わりにする
            if complete_episodes >= 10:
                after = time.time()
                exe_time = after - before
                print('10回連続成功')
                print('Execution Time: {0} sec'.format(round(exe_time, 5)))
                is_episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=2, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=3, bias=True)
# )
# 0エピソード: 199ステップで終了 - rewards: -200
# 1エピソード: 199ステップで終了 - rewards: -200
# 2エピソード: 199ステップで終了 - rewards: -200
# 3エピソード: 199ステップで終了 - rewards: -200
# 4エピソード: 199ステップで終了 - rewards: -200
# 5エピソード: 199ステップで終了 - rewards: -200
# 6エピソード: 199ステップで終了 - rewards: -200
# 7エピソード: 199ステップで終了 - rewards: -200
# 8エピソード: 199ステップで終了 - rewards: -200
# 9エピソード: 199ステップで終了 - rewards: -200
# 10エピソード: 199ステップで終了 - rewards: -200
# 11エピソード: 199ステップで終了 - rewards: -200
# 12エピソード: 199ステップで終了 - rewards: -200
# 13エピソード: 199ステップで終了 - rewards: -200
# 14エピソード: 199ステップで終了 - rewards: -200
# 15エピソード: 199ステップで終了 - rewards: -200
# 16エピソード: 199ステップで終了 - rewards: -200
# 17エピソード: 199ステップで終了 - rewards: -200
# 18エピソード: 199ステップで終了 - rewards: -200
# 19エピソード: 199ステップで終了 - rewards: -200
# 20エピソード: 199ステップで終了 - rewards: -200
# 21エピソード: 199ステップで終了 - rewards: -200
# 22エピソード: 199ステップで終了 - rewards: -200
# 23エピソード: 199ステップで終了 - rewards: -200
# 24エピソード: 199ステップで終了 - rewards: -200
# 25エピソード: 199ステップで終了 - rewards: -200
# 26エピソード: 199ステップで終了 - rewards: -200
# 27エピソード: 199ステップで終了 - rewards: -200
# 28エピソード: 199ステップで終了 - rewards: -200
# 29エピソード: 199ステップで終了 - rewards: -200
# 30エピソード: 199ステップで終了 - rewards: -200
# 31エピソード: 199ステップで終了 - rewards: -200
# 32エピソード: 199ステップで終了 - rewards: -200
# 33エピソード: 199ステップで終了 - rewards: -200
# 34エピソード: 199ステップで終了 - rewards: -200
# 35エピソード: 199ステップで終了 - rewards: -200
# 36エピソード: 199ステップで終了 - rewards: -200
# 37エピソード: 199ステップで終了 - rewards: -200
# 38エピソード: 199ステップで終了 - rewards: -200
# 39エピソード: 199ステップで終了 - rewards: -200
# 40エピソード: 199ステップで終了 - rewards: -200
# 41エピソード: 199ステップで終了 - rewards: -200
# 42エピソード: 199ステップで終了 - rewards: -200
# 43エピソード: 199ステップで終了 - rewards: -200
# 44エピソード: 199ステップで終了 - rewards: -200
# 45エピソード: 199ステップで終了 - rewards: -200
# 46エピソード: 199ステップで終了 - rewards: -200
# 47エピソード: 199ステップで終了 - rewards: -200
# 48エピソード: 199ステップで終了 - rewards: -200
# 49エピソード: 199ステップで終了 - rewards: -200
# 50エピソード: 199ステップで終了 - rewards: -200
# 51エピソード: 199ステップで終了 - rewards: -200
# 52エピソード: 199ステップで終了 - rewards: -200
# 53エピソード: 199ステップで終了 - rewards: -200
# 54エピソード: 199ステップで終了 - rewards: -200
# 55エピソード: 199ステップで終了 - rewards: -200
# 56エピソード: 199ステップで終了 - rewards: -200
# 57エピソード: 199ステップで終了 - rewards: -200
# 58エピソード: 199ステップで終了 - rewards: -200
# 59エピソード: 199ステップで終了 - rewards: -200
# 60エピソード: 199ステップで終了 - rewards: -200
# 61エピソード: 199ステップで終了 - rewards: -200
# 62エピソード: 199ステップで終了 - rewards: -200
# 63エピソード: 199ステップで終了 - rewards: -200
# 64エピソード: 199ステップで終了 - rewards: -200
# 65エピソード: 199ステップで終了 - rewards: -200
# 66エピソード: 199ステップで終了 - rewards: -200
# 67エピソード: 199ステップで終了 - rewards: -200
# 68エピソード: 199ステップで終了 - rewards: -200
# 69エピソード: 199ステップで終了 - rewards: -200
# 70エピソード: 199ステップで終了 - rewards: -200
# 71エピソード: 199ステップで終了 - rewards: -200
# 72エピソード: 199ステップで終了 - rewards: -200
# 73エピソード: 199ステップで終了 - rewards: -200
# 74エピソード: 199ステップで終了 - rewards: -200
# 75エピソード: 199ステップで終了 - rewards: -200
# 76エピソード: 199ステップで終了 - rewards: -200
# 77エピソード: 199ステップで終了 - rewards: -200
# 78エピソード: 199ステップで終了 - rewards: -200
# 79エピソード: 199ステップで終了 - rewards: -200
# 80エピソード: 199ステップで終了 - rewards: -200
# 81エピソード: 199ステップで終了 - rewards: -200
# 82エピソード: 199ステップで終了 - rewards: -200
# 83エピソード: 199ステップで終了 - rewards: -200
# 84エピソード: 199ステップで終了 - rewards: -200
# 85エピソード: 199ステップで終了 - rewards: -200
# 86エピソード: 199ステップで終了 - rewards: -200
# 87エピソード: 199ステップで終了 - rewards: -200
# 88エピソード: 199ステップで終了 - rewards: -200
# 89エピソード: 199ステップで終了 - rewards: -200
# 90エピソード: 199ステップで終了 - rewards: -200
# 91エピソード: 199ステップで終了 - rewards: -200
# 92エピソード: 199ステップで終了 - rewards: -200
# 93エピソード: 199ステップで終了 - rewards: -200
# 94エピソード: 199ステップで終了 - rewards: -200
# 95エピソード: 199ステップで終了 - rewards: -200
# 96エピソード: 199ステップで終了 - rewards: -200
# 97エピソード: 199ステップで終了 - rewards: -200
# 98エピソード: 199ステップで終了 - rewards: -200
# 99エピソード: 199ステップで終了 - rewards: -200
# 100エピソード: 199ステップで終了 - rewards: -200
# 101エピソード: 199ステップで終了 - rewards: -200
# 102エピソード: 199ステップで終了 - rewards: -200
# 103エピソード: 199ステップで終了 - rewards: -200
# 104エピソード: 199ステップで終了 - rewards: -200
# 105エピソード: 199ステップで終了 - rewards: -200
# 106エピソード: 199ステップで終了 - rewards: -200
# 107エピソード: 199ステップで終了 - rewards: -200
# 108エピソード: 199ステップで終了 - rewards: -200
# 109エピソード: 199ステップで終了 - rewards: -200
# 110エピソード: 199ステップで終了 - rewards: -200
# 111エピソード: 199ステップで終了 - rewards: -200
# 112エピソード: 199ステップで終了 - rewards: -200
# 113エピソード: 199ステップで終了 - rewards: -200
# 114エピソード: 199ステップで終了 - rewards: -200
# 115エピソード: 199ステップで終了 - rewards: -200
# 116エピソード: 199ステップで終了 - rewards: -200
# 117エピソード: 199ステップで終了 - rewards: -200
# 118エピソード: 199ステップで終了 - rewards: -200
# 119エピソード: 199ステップで終了 - rewards: -200
# 120エピソード: 199ステップで終了 - rewards: -200
# 121エピソード: 199ステップで終了 - rewards: -200
# 122エピソード: 199ステップで終了 - rewards: -200
# 123エピソード: 199ステップで終了 - rewards: -200
# 124エピソード: 199ステップで終了 - rewards: -200
# 125エピソード: 199ステップで終了 - rewards: -200
# 126エピソード: 199ステップで終了 - rewards: -200
# 127エピソード: 199ステップで終了 - rewards: -200
# 128エピソード: 199ステップで終了 - rewards: -200
# 129エピソード: 199ステップで終了 - rewards: -200
# 130エピソード: 199ステップで終了 - rewards: -200
# 131エピソード: 199ステップで終了 - rewards: -200
# 132エピソード: 199ステップで終了 - rewards: -200
# 133エピソード: 199ステップで終了 - rewards: -200
# 134エピソード: 199ステップで終了 - rewards: -200
# 135エピソード: 199ステップで終了 - rewards: -200
# 136エピソード: 199ステップで終了 - rewards: -200
# 137エピソード: 199ステップで終了 - rewards: -200
# 138エピソード: 199ステップで終了 - rewards: -200
# 139エピソード: 199ステップで終了 - rewards: -200
# 140エピソード: 199ステップで終了 - rewards: -200
# 141エピソード: 199ステップで終了 - rewards: -200
# 142エピソード: 199ステップで終了 - rewards: -200
# 143エピソード: 199ステップで終了 - rewards: -200
# 144エピソード: 199ステップで終了 - rewards: -200
# 145エピソード: 199ステップで終了 - rewards: -200
# 146エピソード: 199ステップで終了 - rewards: -200
# 147エピソード: 199ステップで終了 - rewards: -200
# 148エピソード: 199ステップで終了 - rewards: -200
# 149エピソード: 185ステップで終了 - rewards: -185
# 150エピソード: 199ステップで終了 - rewards: -200
# 151エピソード: 199ステップで終了 - rewards: -200
# 152エピソード: 199ステップで終了 - rewards: -200
# 153エピソード: 199ステップで終了 - rewards: -200
# 154エピソード: 199ステップで終了 - rewards: -200
# 155エピソード: 199ステップで終了 - rewards: -200
# 156エピソード: 199ステップで終了 - rewards: -200
# 157エピソード: 199ステップで終了 - rewards: -200
# 158エピソード: 199ステップで終了 - rewards: -200
# 159エピソード: 199ステップで終了 - rewards: -200
# 160エピソード: 199ステップで終了 - rewards: -200
# 161エピソード: 199ステップで終了 - rewards: -200
# 162エピソード: 199ステップで終了 - rewards: -200
# 163エピソード: 199ステップで終了 - rewards: -200
# 164エピソード: 199ステップで終了 - rewards: -200
# 165エピソード: 199ステップで終了 - rewards: -200
# 166エピソード: 199ステップで終了 - rewards: -200
# 167エピソード: 199ステップで終了 - rewards: -200
# 168エピソード: 199ステップで終了 - rewards: -200
# 169エピソード: 199ステップで終了 - rewards: -200
# 170エピソード: 173ステップで終了 - rewards: -173
# 171エピソード: 199ステップで終了 - rewards: -200
# 172エピソード: 199ステップで終了 - rewards: -200
# 173エピソード: 199ステップで終了 - rewards: -200
# 174エピソード: 199ステップで終了 - rewards: -200
# 175エピソード: 199ステップで終了 - rewards: -200
# 176エピソード: 199ステップで終了 - rewards: -200
# 177エピソード: 199ステップで終了 - rewards: -200
# 178エピソード: 199ステップで終了 - rewards: -200
# 179エピソード: 199ステップで終了 - rewards: -200
# 180エピソード: 199ステップで終了 - rewards: -200
# 181エピソード: 199ステップで終了 - rewards: -200
# 182エピソード: 199ステップで終了 - rewards: -200
# 183エピソード: 199ステップで終了 - rewards: -200
# 184エピソード: 199ステップで終了 - rewards: -200
# 185エピソード: 199ステップで終了 - rewards: -200
# 186エピソード: 199ステップで終了 - rewards: -200
# 187エピソード: 199ステップで終了 - rewards: -200
# 188エピソード: 199ステップで終了 - rewards: -200
# 189エピソード: 199ステップで終了 - rewards: -200
# 190エピソード: 199ステップで終了 - rewards: -200
# 191エピソード: 199ステップで終了 - rewards: -200
# 192エピソード: 199ステップで終了 - rewards: -200
# 193エピソード: 199ステップで終了 - rewards: -200
# 194エピソード: 199ステップで終了 - rewards: -200
# 195エピソード: 199ステップで終了 - rewards: -200
# 196エピソード: 199ステップで終了 - rewards: -200
# 197エピソード: 199ステップで終了 - rewards: -200
# 198エピソード: 199ステップで終了 - rewards: -200
# 199エピソード: 199ステップで終了 - rewards: -200
# 200エピソード: 199ステップで終了 - rewards: -200
# 201エピソード: 199ステップで終了 - rewards: -200
# 202エピソード: 199ステップで終了 - rewards: -200
# 203エピソード: 199ステップで終了 - rewards: -200
# 204エピソード: 152ステップで終了 - rewards: -152
# 205エピソード: 199ステップで終了 - rewards: -200
# 206エピソード: 199ステップで終了 - rewards: -200
# 207エピソード: 199ステップで終了 - rewards: -200
# 208エピソード: 199ステップで終了 - rewards: -200
# 209エピソード: 176ステップで終了 - rewards: -176
# 210エピソード: 199ステップで終了 - rewards: -200
# 211エピソード: 199ステップで終了 - rewards: -200
# 212エピソード: 199ステップで終了 - rewards: -200
# 213エピソード: 199ステップで終了 - rewards: -200
# 214エピソード: 199ステップで終了 - rewards: -200
# 215エピソード: 199ステップで終了 - rewards: -200
# 216エピソード: 199ステップで終了 - rewards: -200
# 217エピソード: 199ステップで終了 - rewards: -200
# 218エピソード: 199ステップで終了 - rewards: -200
# 219エピソード: 199ステップで終了 - rewards: -200
# 220エピソード: 199ステップで終了 - rewards: -200
# 221エピソード: 199ステップで終了 - rewards: -200
# 222エピソード: 199ステップで終了 - rewards: -200
# 223エピソード: 199ステップで終了 - rewards: -200
# 224エピソード: 199ステップで終了 - rewards: -200
# 225エピソード: 199ステップで終了 - rewards: -200
# 226エピソード: 199ステップで終了 - rewards: -200
# 227エピソード: 199ステップで終了 - rewards: -200
# 228エピソード: 199ステップで終了 - rewards: -200
# 229エピソード: 199ステップで終了 - rewards: -200
# 230エピソード: 199ステップで終了 - rewards: -200
# 231エピソード: 199ステップで終了 - rewards: -200
# 232エピソード: 199ステップで終了 - rewards: -200
# 233エピソード: 199ステップで終了 - rewards: -200
# 234エピソード: 199ステップで終了 - rewards: -200
# 235エピソード: 199ステップで終了 - rewards: -200
# 236エピソード: 199ステップで終了 - rewards: -200
# 237エピソード: 199ステップで終了 - rewards: -200
# 238エピソード: 199ステップで終了 - rewards: -200
# 239エピソード: 199ステップで終了 - rewards: -200
# 240エピソード: 199ステップで終了 - rewards: -200
# 241エピソード: 199ステップで終了 - rewards: -200
# 242エピソード: 199ステップで終了 - rewards: -200
# 243エピソード: 199ステップで終了 - rewards: -200
# 244エピソード: 199ステップで終了 - rewards: -200
# 245エピソード: 199ステップで終了 - rewards: -200
# 246エピソード: 199ステップで終了 - rewards: -200
# 247エピソード: 199ステップで終了 - rewards: -200
# 248エピソード: 199ステップで終了 - rewards: -200
# 249エピソード: 199ステップで終了 - rewards: -200
# 250エピソード: 199ステップで終了 - rewards: -200
# 251エピソード: 199ステップで終了 - rewards: -200
# 252エピソード: 199ステップで終了 - rewards: -200
# 253エピソード: 199ステップで終了 - rewards: -200
# 254エピソード: 199ステップで終了 - rewards: -200
# 255エピソード: 199ステップで終了 - rewards: -200
# 256エピソード: 199ステップで終了 - rewards: -200
# 257エピソード: 199ステップで終了 - rewards: -200
# 258エピソード: 199ステップで終了 - rewards: -200
# 259エピソード: 157ステップで終了 - rewards: -157
# 260エピソード: 199ステップで終了 - rewards: -200
# 261エピソード: 199ステップで終了 - rewards: -200
# 262エピソード: 199ステップで終了 - rewards: -200
# 263エピソード: 199ステップで終了 - rewards: -200
# 264エピソード: 199ステップで終了 - rewards: -200
# 265エピソード: 199ステップで終了 - rewards: -200
# 266エピソード: 168ステップで終了 - rewards: -168
# 267エピソード: 199ステップで終了 - rewards: -200
# 268エピソード: 199ステップで終了 - rewards: -200
# 269エピソード: 199ステップで終了 - rewards: -200
# 270エピソード: 199ステップで終了 - rewards: -200
# 271エピソード: 199ステップで終了 - rewards: -200
# 272エピソード: 199ステップで終了 - rewards: -200
# 273エピソード: 199ステップで終了 - rewards: -200
# 274エピソード: 199ステップで終了 - rewards: -200
# 275エピソード: 199ステップで終了 - rewards: -200
# 276エピソード: 199ステップで終了 - rewards: -200
# 277エピソード: 199ステップで終了 - rewards: -200
# 278エピソード: 199ステップで終了 - rewards: -200
# 279エピソード: 199ステップで終了 - rewards: -200
# 280エピソード: 199ステップで終了 - rewards: -200
# 281エピソード: 199ステップで終了 - rewards: -200
# 282エピソード: 199ステップで終了 - rewards: -200
# 283エピソード: 199ステップで終了 - rewards: -200
# 284エピソード: 199ステップで終了 - rewards: -200
# 285エピソード: 199ステップで終了 - rewards: -200
# 286エピソード: 199ステップで終了 - rewards: -200
# 287エピソード: 199ステップで終了 - rewards: -200
# 288エピソード: 199ステップで終了 - rewards: -200
# 289エピソード: 199ステップで終了 - rewards: -200
# 290エピソード: 199ステップで終了 - rewards: -200
# 291エピソード: 180ステップで終了 - rewards: -180
# 292エピソード: 199ステップで終了 - rewards: -200
# 293エピソード: 199ステップで終了 - rewards: -200
# 294エピソード: 199ステップで終了 - rewards: -200
# 295エピソード: 199ステップで終了 - rewards: -200
# 296エピソード: 199ステップで終了 - rewards: -200
# 297エピソード: 199ステップで終了 - rewards: -200
# 298エピソード: 199ステップで終了 - rewards: -200
# 299エピソード: 199ステップで終了 - rewards: -200
# 300エピソード: 199ステップで終了 - rewards: -200
# 301エピソード: 199ステップで終了 - rewards: -200
# 302エピソード: 199ステップで終了 - rewards: -200
# 303エピソード: 199ステップで終了 - rewards: -200
# 304エピソード: 199ステップで終了 - rewards: -200
# 305エピソード: 199ステップで終了 - rewards: -200
# 306エピソード: 199ステップで終了 - rewards: -200
# 307エピソード: 199ステップで終了 - rewards: -200
# 308エピソード: 199ステップで終了 - rewards: -200
# 309エピソード: 199ステップで終了 - rewards: -200
# 310エピソード: 179ステップで終了 - rewards: -179
# 311エピソード: 199ステップで終了 - rewards: -200
# 312エピソード: 199ステップで終了 - rewards: -200
# 313エピソード: 199ステップで終了 - rewards: -200
# 314エピソード: 199ステップで終了 - rewards: -200
# 315エピソード: 199ステップで終了 - rewards: -200
# 316エピソード: 199ステップで終了 - rewards: -200
# 317エピソード: 190ステップで終了 - rewards: -190
# 318エピソード: 199ステップで終了 - rewards: -200
# 319エピソード: 199ステップで終了 - rewards: -200
# 320エピソード: 199ステップで終了 - rewards: -200
# 321エピソード: 199ステップで終了 - rewards: -200
# 322エピソード: 199ステップで終了 - rewards: -200
# 323エピソード: 199ステップで終了 - rewards: -200
# 324エピソード: 199ステップで終了 - rewards: -200
# 325エピソード: 199ステップで終了 - rewards: -200
# 326エピソード: 199ステップで終了 - rewards: -200
# 327エピソード: 199ステップで終了 - rewards: -200
# 328エピソード: 199ステップで終了 - rewards: -200
# 329エピソード: 199ステップで終了 - rewards: -200
# 330エピソード: 199ステップで終了 - rewards: -200
# 331エピソード: 199ステップで終了 - rewards: -200
# 332エピソード: 199ステップで終了 - rewards: -200
# 333エピソード: 199ステップで終了 - rewards: -200
# 334エピソード: 199ステップで終了 - rewards: -200
# 335エピソード: 199ステップで終了 - rewards: -200
# 336エピソード: 199ステップで終了 - rewards: -200
# 337エピソード: 199ステップで終了 - rewards: -200
# 338エピソード: 199ステップで終了 - rewards: -200
# 339エピソード: 199ステップで終了 - rewards: -200
# 340エピソード: 199ステップで終了 - rewards: -200
# 341エピソード: 199ステップで終了 - rewards: -200
# 342エピソード: 199ステップで終了 - rewards: -200
# 343エピソード: 199ステップで終了 - rewards: -200
# 344エピソード: 199ステップで終了 - rewards: -200
# 345エピソード: 199ステップで終了 - rewards: -200
# 346エピソード: 199ステップで終了 - rewards: -200
# 347エピソード: 199ステップで終了 - rewards: -200
# 348エピソード: 199ステップで終了 - rewards: -200
# 349エピソード: 199ステップで終了 - rewards: -200
# 350エピソード: 199ステップで終了 - rewards: -200
# 351エピソード: 199ステップで終了 - rewards: -200
# 352エピソード: 199ステップで終了 - rewards: -200
# 353エピソード: 164ステップで終了 - rewards: -164
# 354エピソード: 199ステップで終了 - rewards: -200
# 355エピソード: 199ステップで終了 - rewards: -200
# 356エピソード: 199ステップで終了 - rewards: -200
# 357エピソード: 199ステップで終了 - rewards: -200
# 358エピソード: 199ステップで終了 - rewards: -200
# 359エピソード: 199ステップで終了 - rewards: -200
# 360エピソード: 199ステップで終了 - rewards: -200
# 361エピソード: 199ステップで終了 - rewards: -200
# 362エピソード: 199ステップで終了 - rewards: -200
# 363エピソード: 199ステップで終了 - rewards: -200
# 364エピソード: 199ステップで終了 - rewards: -200
# 365エピソード: 180ステップで終了 - rewards: -180
# 366エピソード: 199ステップで終了 - rewards: -200
# 367エピソード: 199ステップで終了 - rewards: -200
# 368エピソード: 199ステップで終了 - rewards: -200
# 369エピソード: 199ステップで終了 - rewards: -200
# 370エピソード: 199ステップで終了 - rewards: -200
# 371エピソード: 199ステップで終了 - rewards: -200
# 372エピソード: 199ステップで終了 - rewards: -200
# 373エピソード: 199ステップで終了 - rewards: -200
# 374エピソード: 137ステップで終了 - rewards: -137
# 375エピソード: 199ステップで終了 - rewards: -200
# 376エピソード: 199ステップで終了 - rewards: -200
# 377エピソード: 199ステップで終了 - rewards: -200
# 378エピソード: 199ステップで終了 - rewards: -200
# 379エピソード: 199ステップで終了 - rewards: -200
# 380エピソード: 199ステップで終了 - rewards: -200
# 381エピソード: 199ステップで終了 - rewards: -200
# 382エピソード: 199ステップで終了 - rewards: -200
# 383エピソード: 199ステップで終了 - rewards: -200
# 384エピソード: 199ステップで終了 - rewards: -200
# 385エピソード: 199ステップで終了 - rewards: -200
# 386エピソード: 199ステップで終了 - rewards: -200
# 387エピソード: 199ステップで終了 - rewards: -200
# 388エピソード: 199ステップで終了 - rewards: -200
# 389エピソード: 199ステップで終了 - rewards: -200
# 390エピソード: 199ステップで終了 - rewards: -200
# 391エピソード: 199ステップで終了 - rewards: -200
# 392エピソード: 199ステップで終了 - rewards: -200
# 393エピソード: 199ステップで終了 - rewards: -200
# 394エピソード: 199ステップで終了 - rewards: -200
# 395エピソード: 199ステップで終了 - rewards: -200
# 396エピソード: 199ステップで終了 - rewards: -200
# 397エピソード: 199ステップで終了 - rewards: -200
# 398エピソード: 199ステップで終了 - rewards: -200
# 399エピソード: 196ステップで終了 - rewards: -196
# 400エピソード: 176ステップで終了 - rewards: -176
# 401エピソード: 199ステップで終了 - rewards: -200
# 402エピソード: 199ステップで終了 - rewards: -200
# 403エピソード: 199ステップで終了 - rewards: -200
# 404エピソード: 199ステップで終了 - rewards: -200
# 405エピソード: 148ステップで終了 - rewards: -148
# 406エピソード: 199ステップで終了 - rewards: -200
# 407エピソード: 199ステップで終了 - rewards: -200
# 408エピソード: 199ステップで終了 - rewards: -200
# 409エピソード: 199ステップで終了 - rewards: -200
# 410エピソード: 180ステップで終了 - rewards: -180
# 411エピソード: 199ステップで終了 - rewards: -200
# 412エピソード: 199ステップで終了 - rewards: -200
# 413エピソード: 199ステップで終了 - rewards: -200
# 414エピソード: 199ステップで終了 - rewards: -200
# 415エピソード: 199ステップで終了 - rewards: -200
# 416エピソード: 199ステップで終了 - rewards: -200
# 417エピソード: 199ステップで終了 - rewards: -200
# 418エピソード: 199ステップで終了 - rewards: -200
# 419エピソード: 199ステップで終了 - rewards: -200
# 420エピソード: 199ステップで終了 - rewards: -200
# 421エピソード: 199ステップで終了 - rewards: -200
# 422エピソード: 199ステップで終了 - rewards: -200
# 423エピソード: 199ステップで終了 - rewards: -200
# 424エピソード: 199ステップで終了 - rewards: -200
# 425エピソード: 199ステップで終了 - rewards: -200
# 426エピソード: 199ステップで終了 - rewards: -200
# 427エピソード: 199ステップで終了 - rewards: -200
# 428エピソード: 199ステップで終了 - rewards: -200
# 429エピソード: 199ステップで終了 - rewards: -200
# 430エピソード: 199ステップで終了 - rewards: -200
# 431エピソード: 199ステップで終了 - rewards: -200
# 432エピソード: 199ステップで終了 - rewards: -200
# 433エピソード: 199ステップで終了 - rewards: -200
# 434エピソード: 128ステップで終了 - rewards: -128
# 435エピソード: 199ステップで終了 - rewards: -200
# 436エピソード: 199ステップで終了 - rewards: -200
# 437エピソード: 199ステップで終了 - rewards: -200
# 438エピソード: 199ステップで終了 - rewards: -200
# 439エピソード: 199ステップで終了 - rewards: -200
# 440エピソード: 199ステップで終了 - rewards: -200
# 441エピソード: 199ステップで終了 - rewards: -200
# 442エピソード: 199ステップで終了 - rewards: -200
# 443エピソード: 199ステップで終了 - rewards: -200
# 444エピソード: 199ステップで終了 - rewards: -200
# 445エピソード: 199ステップで終了 - rewards: -200
# 446エピソード: 199ステップで終了 - rewards: -200
# 447エピソード: 199ステップで終了 - rewards: -200
# 448エピソード: 199ステップで終了 - rewards: -200
# 449エピソード: 199ステップで終了 - rewards: -200
# 450エピソード: 199ステップで終了 - rewards: -200
# 451エピソード: 199ステップで終了 - rewards: -200
# 452エピソード: 199ステップで終了 - rewards: -200
# 453エピソード: 199ステップで終了 - rewards: -200
# 454エピソード: 199ステップで終了 - rewards: -200
# 455エピソード: 199ステップで終了 - rewards: -200
# 456エピソード: 199ステップで終了 - rewards: -200
# 457エピソード: 199ステップで終了 - rewards: -200
# 458エピソード: 199ステップで終了 - rewards: -200
# 459エピソード: 199ステップで終了 - rewards: -200
# 460エピソード: 199ステップで終了 - rewards: -200
# 461エピソード: 199ステップで終了 - rewards: -200
# 462エピソード: 199ステップで終了 - rewards: -200
# 463エピソード: 199ステップで終了 - rewards: -200
# 464エピソード: 199ステップで終了 - rewards: -200
# 465エピソード: 199ステップで終了 - rewards: -200
# 466エピソード: 199ステップで終了 - rewards: -200
# 467エピソード: 199ステップで終了 - rewards: -200
# 468エピソード: 199ステップで終了 - rewards: -200
# 469エピソード: 199ステップで終了 - rewards: -200
# 470エピソード: 199ステップで終了 - rewards: -200
# 471エピソード: 199ステップで終了 - rewards: -200
# 472エピソード: 199ステップで終了 - rewards: -200
# 473エピソード: 199ステップで終了 - rewards: -200
# 474エピソード: 199ステップで終了 - rewards: -200
# 475エピソード: 199ステップで終了 - rewards: -200
# 476エピソード: 199ステップで終了 - rewards: -200
# 477エピソード: 199ステップで終了 - rewards: -200
# 478エピソード: 199ステップで終了 - rewards: -200
# 479エピソード: 168ステップで終了 - rewards: -168
# 480エピソード: 199ステップで終了 - rewards: -200
# 481エピソード: 199ステップで終了 - rewards: -200
# 482エピソード: 199ステップで終了 - rewards: -200
# 483エピソード: 199ステップで終了 - rewards: -200
# 484エピソード: 199ステップで終了 - rewards: -200
# 485エピソード: 199ステップで終了 - rewards: -200
# 486エピソード: 173ステップで終了 - rewards: -173
# 487エピソード: 199ステップで終了 - rewards: -200
# 488エピソード: 199ステップで終了 - rewards: -200
# 489エピソード: 171ステップで終了 - rewards: -171
# 490エピソード: 199ステップで終了 - rewards: -200
# 491エピソード: 199ステップで終了 - rewards: -200
# 492エピソード: 199ステップで終了 - rewards: -200
# 493エピソード: 199ステップで終了 - rewards: -200
# 494エピソード: 199ステップで終了 - rewards: -200
# 495エピソード: 199ステップで終了 - rewards: -200
# 496エピソード: 199ステップで終了 - rewards: -200
# 497エピソード: 199ステップで終了 - rewards: -200
# 498エピソード: 199ステップで終了 - rewards: -200
# 499エピソード: 199ステップで終了 - rewards: -200
# 500エピソード: 199ステップで終了 - rewards: -200
# 501エピソード: 199ステップで終了 - rewards: -200
# 502エピソード: 199ステップで終了 - rewards: -200
# 503エピソード: 199ステップで終了 - rewards: -200
# 504エピソード: 199ステップで終了 - rewards: -200
# 505エピソード: 199ステップで終了 - rewards: -200
# 506エピソード: 199ステップで終了 - rewards: -200
# 507エピソード: 199ステップで終了 - rewards: -200
# 508エピソード: 199ステップで終了 - rewards: -200
# 509エピソード: 199ステップで終了 - rewards: -200
# 510エピソード: 199ステップで終了 - rewards: -200
# 511エピソード: 199ステップで終了 - rewards: -200
# 512エピソード: 199ステップで終了 - rewards: -200
# 513エピソード: 199ステップで終了 - rewards: -200
# 514エピソード: 199ステップで終了 - rewards: -200
# 515エピソード: 199ステップで終了 - rewards: -200
# 516エピソード: 152ステップで終了 - rewards: -152
# 517エピソード: 164ステップで終了 - rewards: -164
# 518エピソード: 199ステップで終了 - rewards: -200
# 519エピソード: 199ステップで終了 - rewards: -200
# 520エピソード: 199ステップで終了 - rewards: -200
# 521エピソード: 199ステップで終了 - rewards: -200
# 522エピソード: 199ステップで終了 - rewards: -200
# 523エピソード: 199ステップで終了 - rewards: -200
# 524エピソード: 199ステップで終了 - rewards: -200
# 525エピソード: 199ステップで終了 - rewards: -200
# 526エピソード: 199ステップで終了 - rewards: -200
# 527エピソード: 199ステップで終了 - rewards: -200
# 528エピソード: 199ステップで終了 - rewards: -200
# 529エピソード: 199ステップで終了 - rewards: -200
# 530エピソード: 199ステップで終了 - rewards: -200
# 531エピソード: 199ステップで終了 - rewards: -200
# 532エピソード: 199ステップで終了 - rewards: -200
# 533エピソード: 199ステップで終了 - rewards: -200
# 534エピソード: 199ステップで終了 - rewards: -200
# 535エピソード: 199ステップで終了 - rewards: -200
# 536エピソード: 199ステップで終了 - rewards: -200
# 537エピソード: 199ステップで終了 - rewards: -200
# 538エピソード: 199ステップで終了 - rewards: -200
# 539エピソード: 171ステップで終了 - rewards: -171
# 540エピソード: 199ステップで終了 - rewards: -200
# 541エピソード: 199ステップで終了 - rewards: -200
# 542エピソード: 199ステップで終了 - rewards: -200
# 543エピソード: 199ステップで終了 - rewards: -200
# 544エピソード: 199ステップで終了 - rewards: -200
# 545エピソード: 199ステップで終了 - rewards: -200
# 546エピソード: 199ステップで終了 - rewards: -200
# 547エピソード: 155ステップで終了 - rewards: -155
# 548エピソード: 199ステップで終了 - rewards: -200
# 549エピソード: 199ステップで終了 - rewards: -200
# 550エピソード: 199ステップで終了 - rewards: -200
# 551エピソード: 199ステップで終了 - rewards: -200
# 552エピソード: 199ステップで終了 - rewards: -200
# 553エピソード: 199ステップで終了 - rewards: -200
# 554エピソード: 199ステップで終了 - rewards: -200
# 555エピソード: 199ステップで終了 - rewards: -200
# 556エピソード: 199ステップで終了 - rewards: -200
# 557エピソード: 173ステップで終了 - rewards: -173
# 558エピソード: 199ステップで終了 - rewards: -200
# 559エピソード: 199ステップで終了 - rewards: -200
# 560エピソード: 199ステップで終了 - rewards: -200
# 561エピソード: 199ステップで終了 - rewards: -200
# 562エピソード: 199ステップで終了 - rewards: -200
# 563エピソード: 199ステップで終了 - rewards: -200
# 564エピソード: 199ステップで終了 - rewards: -200
# 565エピソード: 199ステップで終了 - rewards: -200
# 566エピソード: 199ステップで終了 - rewards: -200
# 567エピソード: 199ステップで終了 - rewards: -200
# 568エピソード: 199ステップで終了 - rewards: -200
# 569エピソード: 199ステップで終了 - rewards: -200
# 570エピソード: 199ステップで終了 - rewards: -200
# 571エピソード: 199ステップで終了 - rewards: -200
# 572エピソード: 199ステップで終了 - rewards: -200
# 573エピソード: 199ステップで終了 - rewards: -200
# 574エピソード: 199ステップで終了 - rewards: -200
# 575エピソード: 199ステップで終了 - rewards: -200
# 576エピソード: 199ステップで終了 - rewards: -200
# 577エピソード: 199ステップで終了 - rewards: -200
# 578エピソード: 199ステップで終了 - rewards: -200
# 579エピソード: 199ステップで終了 - rewards: -200
# 580エピソード: 199ステップで終了 - rewards: -200
# 581エピソード: 179ステップで終了 - rewards: -179
# 582エピソード: 199ステップで終了 - rewards: -200
# 583エピソード: 199ステップで終了 - rewards: -200
# 584エピソード: 117ステップで終了 - rewards: -117
# 585エピソード: 199ステップで終了 - rewards: -200
# 586エピソード: 199ステップで終了 - rewards: -200
# 587エピソード: 199ステップで終了 - rewards: -200
# 588エピソード: 185ステップで終了 - rewards: -185
# 589エピソード: 199ステップで終了 - rewards: -200
# 590エピソード: 173ステップで終了 - rewards: -173
# 591エピソード: 199ステップで終了 - rewards: -200
# 592エピソード: 199ステップで終了 - rewards: -200
# 593エピソード: 199ステップで終了 - rewards: -200
# 594エピソード: 199ステップで終了 - rewards: -200
# 595エピソード: 199ステップで終了 - rewards: -200
# 596エピソード: 199ステップで終了 - rewards: -200
# 597エピソード: 199ステップで終了 - rewards: -200
# 598エピソード: 199ステップで終了 - rewards: -200
# 599エピソード: 199ステップで終了 - rewards: -200
# 600エピソード: 199ステップで終了 - rewards: -200
# 601エピソード: 170ステップで終了 - rewards: -170
# 602エピソード: 199ステップで終了 - rewards: -200
# 603エピソード: 199ステップで終了 - rewards: -200
# 604エピソード: 199ステップで終了 - rewards: -200
# 605エピソード: 173ステップで終了 - rewards: -173
# 606エピソード: 199ステップで終了 - rewards: -200
# 607エピソード: 199ステップで終了 - rewards: -200
# 608エピソード: 199ステップで終了 - rewards: -200
# 609エピソード: 199ステップで終了 - rewards: -200
# 610エピソード: 199ステップで終了 - rewards: -200
# 611エピソード: 199ステップで終了 - rewards: -200
# 612エピソード: 199ステップで終了 - rewards: -200
# 613エピソード: 199ステップで終了 - rewards: -200
# 614エピソード: 199ステップで終了 - rewards: -200
# 615エピソード: 199ステップで終了 - rewards: -200
# 616エピソード: 199ステップで終了 - rewards: -200
# 617エピソード: 199ステップで終了 - rewards: -200
# 618エピソード: 199ステップで終了 - rewards: -200
# 619エピソード: 199ステップで終了 - rewards: -200
# 620エピソード: 199ステップで終了 - rewards: -200
# 621エピソード: 199ステップで終了 - rewards: -200
# 622エピソード: 199ステップで終了 - rewards: -200
# 623エピソード: 199ステップで終了 - rewards: -200
# 624エピソード: 199ステップで終了 - rewards: -200
# 625エピソード: 199ステップで終了 - rewards: -200
# 626エピソード: 199ステップで終了 - rewards: -200
# 627エピソード: 199ステップで終了 - rewards: -200
# 628エピソード: 199ステップで終了 - rewards: -200
# 629エピソード: 199ステップで終了 - rewards: -200
# 630エピソード: 199ステップで終了 - rewards: -200
# 631エピソード: 199ステップで終了 - rewards: -200
# 632エピソード: 199ステップで終了 - rewards: -200
# 633エピソード: 199ステップで終了 - rewards: -200
# 634エピソード: 199ステップで終了 - rewards: -200
# 635エピソード: 166ステップで終了 - rewards: -166
# 636エピソード: 199ステップで終了 - rewards: -200
# 637エピソード: 199ステップで終了 - rewards: -200
# 638エピソード: 199ステップで終了 - rewards: -200
# 639エピソード: 199ステップで終了 - rewards: -200
# 640エピソード: 199ステップで終了 - rewards: -200
# 641エピソード: 199ステップで終了 - rewards: -200
# 642エピソード: 199ステップで終了 - rewards: -200
# 643エピソード: 199ステップで終了 - rewards: -200
# 644エピソード: 199ステップで終了 - rewards: -200
# 645エピソード: 199ステップで終了 - rewards: -200
# 646エピソード: 199ステップで終了 - rewards: -200
# 647エピソード: 199ステップで終了 - rewards: -200
# 648エピソード: 199ステップで終了 - rewards: -200
# 649エピソード: 199ステップで終了 - rewards: -200
# 650エピソード: 199ステップで終了 - rewards: -200
# 651エピソード: 199ステップで終了 - rewards: -200
# 652エピソード: 173ステップで終了 - rewards: -173
# 653エピソード: 199ステップで終了 - rewards: -200
# 654エピソード: 199ステップで終了 - rewards: -200
# 655エピソード: 199ステップで終了 - rewards: -200
# 656エピソード: 199ステップで終了 - rewards: -200
# 657エピソード: 199ステップで終了 - rewards: -200
# 658エピソード: 188ステップで終了 - rewards: -188
# 659エピソード: 199ステップで終了 - rewards: -200
# 660エピソード: 199ステップで終了 - rewards: -200
# 661エピソード: 199ステップで終了 - rewards: -200
# 662エピソード: 199ステップで終了 - rewards: -200
# 663エピソード: 199ステップで終了 - rewards: -200
# 664エピソード: 199ステップで終了 - rewards: -200
# 665エピソード: 199ステップで終了 - rewards: -200
# 666エピソード: 199ステップで終了 - rewards: -200
# 667エピソード: 199ステップで終了 - rewards: -200
# 668エピソード: 199ステップで終了 - rewards: -200
# 669エピソード: 199ステップで終了 - rewards: -200
# 670エピソード: 199ステップで終了 - rewards: -200
# 671エピソード: 199ステップで終了 - rewards: -200
# 672エピソード: 199ステップで終了 - rewards: -200
# 673エピソード: 199ステップで終了 - rewards: -200
# 674エピソード: 199ステップで終了 - rewards: -200
# 675エピソード: 161ステップで終了 - rewards: -161
# 676エピソード: 199ステップで終了 - rewards: -200
# 677エピソード: 199ステップで終了 - rewards: -200
# 678エピソード: 199ステップで終了 - rewards: -200
# 679エピソード: 199ステップで終了 - rewards: -200
# 680エピソード: 199ステップで終了 - rewards: -200
# 681エピソード: 199ステップで終了 - rewards: -200
# 682エピソード: 199ステップで終了 - rewards: -200
# 683エピソード: 199ステップで終了 - rewards: -200
# 684エピソード: 180ステップで終了 - rewards: -180
# 685エピソード: 199ステップで終了 - rewards: -200
# 686エピソード: 199ステップで終了 - rewards: -200
# 687エピソード: 199ステップで終了 - rewards: -200
# 688エピソード: 199ステップで終了 - rewards: -200
# 689エピソード: 199ステップで終了 - rewards: -200
# 690エピソード: 199ステップで終了 - rewards: -200
# 691エピソード: 199ステップで終了 - rewards: -200
# 692エピソード: 199ステップで終了 - rewards: -200
# 693エピソード: 199ステップで終了 - rewards: -200
# 694エピソード: 199ステップで終了 - rewards: -200
# 695エピソード: 199ステップで終了 - rewards: -200
# 696エピソード: 199ステップで終了 - rewards: -200
# 697エピソード: 199ステップで終了 - rewards: -200
# 698エピソード: 199ステップで終了 - rewards: -200
# 699エピソード: 199ステップで終了 - rewards: -200
# 700エピソード: 199ステップで終了 - rewards: -200
# 701エピソード: 199ステップで終了 - rewards: -200
# 702エピソード: 199ステップで終了 - rewards: -200
# 703エピソード: 199ステップで終了 - rewards: -200
# 704エピソード: 199ステップで終了 - rewards: -200
# 705エピソード: 199ステップで終了 - rewards: -200
# 706エピソード: 199ステップで終了 - rewards: -200
# 707エピソード: 199ステップで終了 - rewards: -200
# 708エピソード: 199ステップで終了 - rewards: -200
# 709エピソード: 199ステップで終了 - rewards: -200
# 710エピソード: 199ステップで終了 - rewards: -200
# 711エピソード: 199ステップで終了 - rewards: -200
# 712エピソード: 199ステップで終了 - rewards: -200
# 713エピソード: 199ステップで終了 - rewards: -200
# 714エピソード: 199ステップで終了 - rewards: -200
# 715エピソード: 199ステップで終了 - rewards: -200
# 716エピソード: 199ステップで終了 - rewards: -200
# 717エピソード: 199ステップで終了 - rewards: -200
# 718エピソード: 199ステップで終了 - rewards: -200
# 719エピソード: 199ステップで終了 - rewards: -200
# 720エピソード: 199ステップで終了 - rewards: -200
# 721エピソード: 199ステップで終了 - rewards: -200
# 722エピソード: 199ステップで終了 - rewards: -200
# 723エピソード: 199ステップで終了 - rewards: -200
# 724エピソード: 199ステップで終了 - rewards: -200
# 725エピソード: 199ステップで終了 - rewards: -200
# 726エピソード: 126ステップで終了 - rewards: -126
# 727エピソード: 199ステップで終了 - rewards: -200
# 728エピソード: 188ステップで終了 - rewards: -188
# 729エピソード: 199ステップで終了 - rewards: -200
# 730エピソード: 199ステップで終了 - rewards: -200
# 731エピソード: 199ステップで終了 - rewards: -200
# 732エピソード: 199ステップで終了 - rewards: -200
# 733エピソード: 199ステップで終了 - rewards: -200
# 734エピソード: 199ステップで終了 - rewards: -200
# 735エピソード: 199ステップで終了 - rewards: -200
# 736エピソード: 199ステップで終了 - rewards: -200
# 737エピソード: 199ステップで終了 - rewards: -200
# 738エピソード: 199ステップで終了 - rewards: -200
# 739エピソード: 199ステップで終了 - rewards: -200
# 740エピソード: 199ステップで終了 - rewards: -200
# 741エピソード: 199ステップで終了 - rewards: -200
# 742エピソード: 199ステップで終了 - rewards: -200
# 743エピソード: 199ステップで終了 - rewards: -200
# 744エピソード: 199ステップで終了 - rewards: -200
# 745エピソード: 172ステップで終了 - rewards: -172
# 746エピソード: 199ステップで終了 - rewards: -200
# 747エピソード: 199ステップで終了 - rewards: -200
# 748エピソード: 199ステップで終了 - rewards: -200
# 749エピソード: 129ステップで終了 - rewards: -129
# 750エピソード: 199ステップで終了 - rewards: -200
# 751エピソード: 190ステップで終了 - rewards: -190
# 752エピソード: 199ステップで終了 - rewards: -200
# 753エピソード: 199ステップで終了 - rewards: -200
# 754エピソード: 188ステップで終了 - rewards: -188
# 755エピソード: 199ステップで終了 - rewards: -200
# 756エピソード: 199ステップで終了 - rewards: -200
# 757エピソード: 199ステップで終了 - rewards: -200
# 758エピソード: 199ステップで終了 - rewards: -200
# 759エピソード: 199ステップで終了 - rewards: -200
# 760エピソード: 199ステップで終了 - rewards: -200
# 761エピソード: 199ステップで終了 - rewards: -200
# 762エピソード: 169ステップで終了 - rewards: -169
# 763エピソード: 199ステップで終了 - rewards: -200
# 764エピソード: 199ステップで終了 - rewards: -200
# 765エピソード: 199ステップで終了 - rewards: -200
# 766エピソード: 199ステップで終了 - rewards: -200
# 767エピソード: 199ステップで終了 - rewards: -200
# 768エピソード: 199ステップで終了 - rewards: -200
# 769エピソード: 159ステップで終了 - rewards: -159
# 770エピソード: 199ステップで終了 - rewards: -200
# 771エピソード: 199ステップで終了 - rewards: -200
# 772エピソード: 196ステップで終了 - rewards: -196
# 773エピソード: 199ステップで終了 - rewards: -200
# 774エピソード: 199ステップで終了 - rewards: -200
# 775エピソード: 199ステップで終了 - rewards: -200
# 776エピソード: 199ステップで終了 - rewards: -200
# 777エピソード: 199ステップで終了 - rewards: -200
# 778エピソード: 199ステップで終了 - rewards: -200
# 779エピソード: 199ステップで終了 - rewards: -200
# 780エピソード: 199ステップで終了 - rewards: -200
# 781エピソード: 140ステップで終了 - rewards: -140
# 782エピソード: 148ステップで終了 - rewards: -148
# 783エピソード: 123ステップで終了 - rewards: -123
# 784エピソード: 199ステップで終了 - rewards: -200
# 785エピソード: 199ステップで終了 - rewards: -200
# 786エピソード: 199ステップで終了 - rewards: -200
# 787エピソード: 199ステップで終了 - rewards: -200
# 788エピソード: 199ステップで終了 - rewards: -200
# 789エピソード: 185ステップで終了 - rewards: -185
# 790エピソード: 193ステップで終了 - rewards: -193
# 791エピソード: 199ステップで終了 - rewards: -200
# 792エピソード: 199ステップで終了 - rewards: -200
# 793エピソード: 143ステップで終了 - rewards: -143
# 794エピソード: 166ステップで終了 - rewards: -166
# 795エピソード: 199ステップで終了 - rewards: -200
# 796エピソード: 178ステップで終了 - rewards: -178
# 797エピソード: 140ステップで終了 - rewards: -140
# 798エピソード: 138ステップで終了 - rewards: -138
# 799エピソード: 199ステップで終了 - rewards: -200
# 800エピソード: 199ステップで終了 - rewards: -200
# 801エピソード: 199ステップで終了 - rewards: -200
# 802エピソード: 199ステップで終了 - rewards: -200
# 803エピソード: 199ステップで終了 - rewards: -200
# 804エピソード: 199ステップで終了 - rewards: -200
# 805エピソード: 199ステップで終了 - rewards: -200
# 806エピソード: 199ステップで終了 - rewards: -200
# 807エピソード: 199ステップで終了 - rewards: -200
# 808エピソード: 199ステップで終了 - rewards: -200
# 809エピソード: 150ステップで終了 - rewards: -150
# 810エピソード: 199ステップで終了 - rewards: -200
# 811エピソード: 199ステップで終了 - rewards: -200
# 812エピソード: 192ステップで終了 - rewards: -192
# 813エピソード: 199ステップで終了 - rewards: -200
# 814エピソード: 199ステップで終了 - rewards: -200
# 815エピソード: 199ステップで終了 - rewards: -200
# 816エピソード: 199ステップで終了 - rewards: -200
# 817エピソード: 199ステップで終了 - rewards: -200
# 818エピソード: 199ステップで終了 - rewards: -200
# 819エピソード: 199ステップで終了 - rewards: -200
# 820エピソード: 135ステップで終了 - rewards: -135
# 821エピソード: 178ステップで終了 - rewards: -178
# 822エピソード: 199ステップで終了 - rewards: -200
# 823エピソード: 199ステップで終了 - rewards: -200
# 824エピソード: 199ステップで終了 - rewards: -200
# 825エピソード: 199ステップで終了 - rewards: -200
# 826エピソード: 199ステップで終了 - rewards: -200
# 827エピソード: 186ステップで終了 - rewards: -186
# 828エピソード: 199ステップで終了 - rewards: -200
# 829エピソード: 199ステップで終了 - rewards: -200
# 830エピソード: 199ステップで終了 - rewards: -200
# 831エピソード: 199ステップで終了 - rewards: -200
# 832エピソード: 199ステップで終了 - rewards: -200
# 833エピソード: 199ステップで終了 - rewards: -200
# 834エピソード: 199ステップで終了 - rewards: -200
# 835エピソード: 199ステップで終了 - rewards: -200
# 836エピソード: 199ステップで終了 - rewards: -200
# 837エピソード: 199ステップで終了 - rewards: -200
# 838エピソード: 199ステップで終了 - rewards: -200
# 839エピソード: 199ステップで終了 - rewards: -200
# 840エピソード: 199ステップで終了 - rewards: -200
# 841エピソード: 199ステップで終了 - rewards: -200
# 842エピソード: 194ステップで終了 - rewards: -194
# 843エピソード: 199ステップで終了 - rewards: -200
# 844エピソード: 199ステップで終了 - rewards: -200
# 845エピソード: 199ステップで終了 - rewards: -200
# 846エピソード: 199ステップで終了 - rewards: -200
# 847エピソード: 182ステップで終了 - rewards: -182
# 848エピソード: 199ステップで終了 - rewards: -200
# 849エピソード: 199ステップで終了 - rewards: -200
# 850エピソード: 199ステップで終了 - rewards: -200
# 851エピソード: 199ステップで終了 - rewards: -200
# 852エピソード: 170ステップで終了 - rewards: -170
# 853エピソード: 199ステップで終了 - rewards: -200
# 854エピソード: 199ステップで終了 - rewards: -200
# 855エピソード: 199ステップで終了 - rewards: -200
# 856エピソード: 171ステップで終了 - rewards: -171
# 857エピソード: 199ステップで終了 - rewards: -200
# 858エピソード: 199ステップで終了 - rewards: -200
# 859エピソード: 199ステップで終了 - rewards: -200
# 860エピソード: 199ステップで終了 - rewards: -200
# 861エピソード: 174ステップで終了 - rewards: -174
# 862エピソード: 199ステップで終了 - rewards: -200
# 863エピソード: 199ステップで終了 - rewards: -200
# 864エピソード: 199ステップで終了 - rewards: -200
# 865エピソード: 199ステップで終了 - rewards: -200
# 866エピソード: 199ステップで終了 - rewards: -200
# 867エピソード: 168ステップで終了 - rewards: -168
# 868エピソード: 199ステップで終了 - rewards: -200
# 869エピソード: 199ステップで終了 - rewards: -200
# 870エピソード: 199ステップで終了 - rewards: -200
# 871エピソード: 187ステップで終了 - rewards: -187
# 872エピソード: 199ステップで終了 - rewards: -200
# 873エピソード: 199ステップで終了 - rewards: -200
# 874エピソード: 199ステップで終了 - rewards: -200
# 875エピソード: 199ステップで終了 - rewards: -200
# 876エピソード: 199ステップで終了 - rewards: -200
# 877エピソード: 199ステップで終了 - rewards: -200
# 878エピソード: 199ステップで終了 - rewards: -200
# 879エピソード: 199ステップで終了 - rewards: -200
# 880エピソード: 199ステップで終了 - rewards: -200
# 881エピソード: 131ステップで終了 - rewards: -131
# 882エピソード: 199ステップで終了 - rewards: -200
# 883エピソード: 199ステップで終了 - rewards: -200
# 884エピソード: 199ステップで終了 - rewards: -200
# 885エピソード: 199ステップで終了 - rewards: -200
# 886エピソード: 199ステップで終了 - rewards: -200
# 887エピソード: 155ステップで終了 - rewards: -155
# 888エピソード: 199ステップで終了 - rewards: -200
# 889エピソード: 199ステップで終了 - rewards: -200
# 890エピソード: 175ステップで終了 - rewards: -175
# 891エピソード: 199ステップで終了 - rewards: -200
# 892エピソード: 199ステップで終了 - rewards: -200
# 893エピソード: 199ステップで終了 - rewards: -200
# 894エピソード: 199ステップで終了 - rewards: -200
# 895エピソード: 199ステップで終了 - rewards: -200
# 896エピソード: 199ステップで終了 - rewards: -200
# 897エピソード: 199ステップで終了 - rewards: -200
# 898エピソード: 199ステップで終了 - rewards: -200
# 899エピソード: 199ステップで終了 - rewards: -200
# 900エピソード: 199ステップで終了 - rewards: -200
# 901エピソード: 199ステップで終了 - rewards: -200
# 902エピソード: 199ステップで終了 - rewards: -200
# 903エピソード: 199ステップで終了 - rewards: -200
# 904エピソード: 199ステップで終了 - rewards: -200
# 905エピソード: 199ステップで終了 - rewards: -200
# 906エピソード: 186ステップで終了 - rewards: -186
# 907エピソード: 199ステップで終了 - rewards: -200
# 908エピソード: 199ステップで終了 - rewards: -200
# 909エピソード: 199ステップで終了 - rewards: -200
# 910エピソード: 199ステップで終了 - rewards: -200
# 911エピソード: 199ステップで終了 - rewards: -200
# 912エピソード: 199ステップで終了 - rewards: -200
# 913エピソード: 199ステップで終了 - rewards: -200
# 914エピソード: 199ステップで終了 - rewards: -200
# 915エピソード: 123ステップで終了 - rewards: -123
# 916エピソード: 199ステップで終了 - rewards: -200
# 917エピソード: 199ステップで終了 - rewards: -200
# 918エピソード: 199ステップで終了 - rewards: -200
# 919エピソード: 199ステップで終了 - rewards: -200
# 920エピソード: 199ステップで終了 - rewards: -200
# 921エピソード: 199ステップで終了 - rewards: -200
# 922エピソード: 199ステップで終了 - rewards: -200
# 923エピソード: 199ステップで終了 - rewards: -200
# 924エピソード: 151ステップで終了 - rewards: -151
# 925エピソード: 180ステップで終了 - rewards: -180
# 926エピソード: 199ステップで終了 - rewards: -200
# 927エピソード: 199ステップで終了 - rewards: -200
# 928エピソード: 199ステップで終了 - rewards: -200
# 929エピソード: 199ステップで終了 - rewards: -200
# 930エピソード: 199ステップで終了 - rewards: -200
# 931エピソード: 156ステップで終了 - rewards: -156
# 932エピソード: 199ステップで終了 - rewards: -200
# 933エピソード: 199ステップで終了 - rewards: -200
# 934エピソード: 199ステップで終了 - rewards: -200
# 935エピソード: 199ステップで終了 - rewards: -200
# 936エピソード: 199ステップで終了 - rewards: -200
# 937エピソード: 199ステップで終了 - rewards: -200
# 938エピソード: 199ステップで終了 - rewards: -200
# 939エピソード: 163ステップで終了 - rewards: -163
# 940エピソード: 199ステップで終了 - rewards: -200
# 941エピソード: 187ステップで終了 - rewards: -187
# 942エピソード: 199ステップで終了 - rewards: -200
# 943エピソード: 199ステップで終了 - rewards: -200
# 944エピソード: 199ステップで終了 - rewards: -200
# 945エピソード: 199ステップで終了 - rewards: -200
# 946エピソード: 199ステップで終了 - rewards: -200
# 947エピソード: 199ステップで終了 - rewards: -200
# 948エピソード: 167ステップで終了 - rewards: -167
# 949エピソード: 179ステップで終了 - rewards: -179
# 950エピソード: 171ステップで終了 - rewards: -171
# 951エピソード: 199ステップで終了 - rewards: -200
# 952エピソード: 199ステップで終了 - rewards: -200
# 953エピソード: 199ステップで終了 - rewards: -200
# 954エピソード: 199ステップで終了 - rewards: -200
# 955エピソード: 199ステップで終了 - rewards: -200
# 956エピソード: 199ステップで終了 - rewards: -200
# 957エピソード: 199ステップで終了 - rewards: -200
# 958エピソード: 144ステップで終了 - rewards: -144
# 959エピソード: 160ステップで終了 - rewards: -160
# 960エピソード: 199ステップで終了 - rewards: -200
# 961エピソード: 199ステップで終了 - rewards: -200
# 962エピソード: 151ステップで終了 - rewards: -151
# 963エピソード: 199ステップで終了 - rewards: -200
# 964エピソード: 199ステップで終了 - rewards: -200
# 965エピソード: 199ステップで終了 - rewards: -200
# 966エピソード: 199ステップで終了 - rewards: -200
# 967エピソード: 199ステップで終了 - rewards: -200
# 968エピソード: 199ステップで終了 - rewards: -200
# 969エピソード: 199ステップで終了 - rewards: -200
# 970エピソード: 199ステップで終了 - rewards: -200
# 971エピソード: 199ステップで終了 - rewards: -200
# 972エピソード: 199ステップで終了 - rewards: -200
# 973エピソード: 199ステップで終了 - rewards: -200
# 974エピソード: 199ステップで終了 - rewards: -200
# 975エピソード: 194ステップで終了 - rewards: -194
# 976エピソード: 199ステップで終了 - rewards: -200
# 977エピソード: 199ステップで終了 - rewards: -200
# 978エピソード: 199ステップで終了 - rewards: -200
# 979エピソード: 199ステップで終了 - rewards: -200
# 980エピソード: 191ステップで終了 - rewards: -191
# 981エピソード: 199ステップで終了 - rewards: -200
# 982エピソード: 199ステップで終了 - rewards: -200
# 983エピソード: 199ステップで終了 - rewards: -200
# 984エピソード: 169ステップで終了 - rewards: -169
# 985エピソード: 199ステップで終了 - rewards: -200
# 986エピソード: 199ステップで終了 - rewards: -200
# 987エピソード: 177ステップで終了 - rewards: -177
# 988エピソード: 199ステップで終了 - rewards: -200
# 989エピソード: 139ステップで終了 - rewards: -139
# 990エピソード: 199ステップで終了 - rewards: -200
# 991エピソード: 199ステップで終了 - rewards: -200
# 992エピソード: 176ステップで終了 - rewards: -176
# 993エピソード: 173ステップで終了 - rewards: -173
# 994エピソード: 199ステップで終了 - rewards: -200
# 995エピソード: 199ステップで終了 - rewards: -200
# 996エピソード: 199ステップで終了 - rewards: -200
# 997エピソード: 199ステップで終了 - rewards: -200
# 998エピソード: 199ステップで終了 - rewards: -200
# 999エピソード: 199ステップで終了 - rewards: -200
# 1000エピソード: 156ステップで終了 - rewards: -156
# 1001エピソード: 199ステップで終了 - rewards: -200
# 1002エピソード: 166ステップで終了 - rewards: -166
# 1003エピソード: 198ステップで終了 - rewards: -198
# 1004エピソード: 199ステップで終了 - rewards: -200
# 1005エピソード: 199ステップで終了 - rewards: -200
# 1006エピソード: 199ステップで終了 - rewards: -200
# 1007エピソード: 179ステップで終了 - rewards: -179
# 1008エピソード: 199ステップで終了 - rewards: -200
# 1009エピソード: 164ステップで終了 - rewards: -164
# 1010エピソード: 199ステップで終了 - rewards: -200
# 1011エピソード: 199ステップで終了 - rewards: -200
# 1012エピソード: 199ステップで終了 - rewards: -200
# 1013エピソード: 199ステップで終了 - rewards: -200
# 1014エピソード: 199ステップで終了 - rewards: -200
# 1015エピソード: 151ステップで終了 - rewards: -151
# 1016エピソード: 199ステップで終了 - rewards: -200
# 1017エピソード: 194ステップで終了 - rewards: -194
# 1018エピソード: 197ステップで終了 - rewards: -197
# 1019エピソード: 199ステップで終了 - rewards: -200
# 1020エピソード: 199ステップで終了 - rewards: -200
# 1021エピソード: 199ステップで終了 - rewards: -200
# 1022エピソード: 199ステップで終了 - rewards: -200
# 1023エピソード: 199ステップで終了 - rewards: -200
# 1024エピソード: 199ステップで終了 - rewards: -200
# 1025エピソード: 176ステップで終了 - rewards: -176
# 1026エピソード: 161ステップで終了 - rewards: -161
# 1027エピソード: 162ステップで終了 - rewards: -162
# 1028エピソード: 199ステップで終了 - rewards: -200
# 1029エピソード: 199ステップで終了 - rewards: -200
# 1030エピソード: 199ステップで終了 - rewards: -200
# 1031エピソード: 199ステップで終了 - rewards: -200
# 1032エピソード: 199ステップで終了 - rewards: -200
# 1033エピソード: 199ステップで終了 - rewards: -200
# 1034エピソード: 199ステップで終了 - rewards: -200
# 1035エピソード: 199ステップで終了 - rewards: -200
# 1036エピソード: 144ステップで終了 - rewards: -144
# 1037エピソード: 199ステップで終了 - rewards: -200
# 1038エピソード: 176ステップで終了 - rewards: -176
# 1039エピソード: 199ステップで終了 - rewards: -200
# 1040エピソード: 199ステップで終了 - rewards: -200
# 1041エピソード: 199ステップで終了 - rewards: -200
# 1042エピソード: 199ステップで終了 - rewards: -200
# 1043エピソード: 137ステップで終了 - rewards: -137
# 1044エピソード: 148ステップで終了 - rewards: -148
# 1045エピソード: 199ステップで終了 - rewards: -200
# 1046エピソード: 199ステップで終了 - rewards: -200
# 1047エピソード: 199ステップで終了 - rewards: -200
# 1048エピソード: 192ステップで終了 - rewards: -192
# 1049エピソード: 199ステップで終了 - rewards: -200
# 1050エピソード: 185ステップで終了 - rewards: -185
# 1051エピソード: 199ステップで終了 - rewards: -200
# 1052エピソード: 199ステップで終了 - rewards: -200
# 1053エピソード: 199ステップで終了 - rewards: -200
# 1054エピソード: 199ステップで終了 - rewards: -200
# 1055エピソード: 199ステップで終了 - rewards: -200
# 1056エピソード: 199ステップで終了 - rewards: -200
# 1057エピソード: 199ステップで終了 - rewards: -200
# 1058エピソード: 199ステップで終了 - rewards: -200
# 1059エピソード: 199ステップで終了 - rewards: -200
# 1060エピソード: 160ステップで終了 - rewards: -160
# 1061エピソード: 197ステップで終了 - rewards: -197
# 1062エピソード: 199ステップで終了 - rewards: -200
# 1063エピソード: 199ステップで終了 - rewards: -200
# 1064エピソード: 199ステップで終了 - rewards: -200
# 1065エピソード: 199ステップで終了 - rewards: -200
# 1066エピソード: 153ステップで終了 - rewards: -153
# 1067エピソード: 199ステップで終了 - rewards: -200
# 1068エピソード: 159ステップで終了 - rewards: -159
# 1069エピソード: 138ステップで終了 - rewards: -138
# 1070エピソード: 155ステップで終了 - rewards: -155
# 1071エピソード: 158ステップで終了 - rewards: -158
# 1072エピソード: 159ステップで終了 - rewards: -159
# 1073エピソード: 164ステップで終了 - rewards: -164
# 1074エピソード: 167ステップで終了 - rewards: -167
# 1075エピソード: 199ステップで終了 - rewards: -200
# 1076エピソード: 199ステップで終了 - rewards: -200
# 1077エピソード: 199ステップで終了 - rewards: -200
# 1078エピソード: 199ステップで終了 - rewards: -200
# 1079エピソード: 176ステップで終了 - rewards: -176
# 1080エピソード: 181ステップで終了 - rewards: -181
# 1081エピソード: 194ステップで終了 - rewards: -194
# 1082エピソード: 199ステップで終了 - rewards: -200
# 1083エピソード: 195ステップで終了 - rewards: -195
# 1084エピソード: 199ステップで終了 - rewards: -200
# 1085エピソード: 158ステップで終了 - rewards: -158
# 1086エピソード: 199ステップで終了 - rewards: -200
# 1087エピソード: 199ステップで終了 - rewards: -200
# 1088エピソード: 199ステップで終了 - rewards: -200
# 1089エピソード: 156ステップで終了 - rewards: -156
# 1090エピソード: 199ステップで終了 - rewards: -200
# 1091エピソード: 199ステップで終了 - rewards: -200
# 1092エピソード: 143ステップで終了 - rewards: -143
# 1093エピソード: 199ステップで終了 - rewards: -200
# 1094エピソード: 199ステップで終了 - rewards: -200
# 1095エピソード: 199ステップで終了 - rewards: -200
# 1096エピソード: 151ステップで終了 - rewards: -151
# 1097エピソード: 199ステップで終了 - rewards: -200
# 1098エピソード: 117ステップで終了 - rewards: -117
# 1099エピソード: 158ステップで終了 - rewards: -158
# 1100エピソード: 199ステップで終了 - rewards: -200
# 1101エピソード: 171ステップで終了 - rewards: -171
# 1102エピソード: 199ステップで終了 - rewards: -200
# 1103エピソード: 193ステップで終了 - rewards: -193
# 1104エピソード: 199ステップで終了 - rewards: -200
# 1105エピソード: 199ステップで終了 - rewards: -200
# 1106エピソード: 199ステップで終了 - rewards: -200
# 1107エピソード: 162ステップで終了 - rewards: -162
# 1108エピソード: 199ステップで終了 - rewards: -200
# 1109エピソード: 199ステップで終了 - rewards: -200
# 1110エピソード: 199ステップで終了 - rewards: -200
# 1111エピソード: 185ステップで終了 - rewards: -185
# 1112エピソード: 199ステップで終了 - rewards: -200
# 1113エピソード: 199ステップで終了 - rewards: -200
# 1114エピソード: 199ステップで終了 - rewards: -200
# 1115エピソード: 173ステップで終了 - rewards: -173
# 1116エピソード: 199ステップで終了 - rewards: -200
# 1117エピソード: 199ステップで終了 - rewards: -200
# 1118エピソード: 199ステップで終了 - rewards: -200
# 1119エピソード: 199ステップで終了 - rewards: -200
# 1120エピソード: 199ステップで終了 - rewards: -200
# 1121エピソード: 199ステップで終了 - rewards: -200
# 1122エピソード: 199ステップで終了 - rewards: -200
# 1123エピソード: 199ステップで終了 - rewards: -200
# 1124エピソード: 199ステップで終了 - rewards: -200
# 1125エピソード: 167ステップで終了 - rewards: -167
# 1126エピソード: 199ステップで終了 - rewards: -200
# 1127エピソード: 199ステップで終了 - rewards: -200
# 1128エピソード: 199ステップで終了 - rewards: -200
# 1129エピソード: 199ステップで終了 - rewards: -200
# 1130エピソード: 198ステップで終了 - rewards: -198
# 1131エピソード: 199ステップで終了 - rewards: -200
# 1132エピソード: 199ステップで終了 - rewards: -200
# 1133エピソード: 199ステップで終了 - rewards: -200
# 1134エピソード: 199ステップで終了 - rewards: -200
# 1135エピソード: 199ステップで終了 - rewards: -200
# 1136エピソード: 199ステップで終了 - rewards: -200
# 1137エピソード: 199ステップで終了 - rewards: -200
# 1138エピソード: 199ステップで終了 - rewards: -200
# 1139エピソード: 160ステップで終了 - rewards: -160
# 1140エピソード: 164ステップで終了 - rewards: -164
# 1141エピソード: 177ステップで終了 - rewards: -177
# 1142エピソード: 199ステップで終了 - rewards: -200
# 1143エピソード: 187ステップで終了 - rewards: -187
# 1144エピソード: 199ステップで終了 - rewards: -200
# 1145エピソード: 199ステップで終了 - rewards: -200
# 1146エピソード: 179ステップで終了 - rewards: -179
# 1147エピソード: 199ステップで終了 - rewards: -200
# 1148エピソード: 199ステップで終了 - rewards: -200
# 1149エピソード: 195ステップで終了 - rewards: -195
# 1150エピソード: 199ステップで終了 - rewards: -200
# 1151エピソード: 189ステップで終了 - rewards: -189
# 1152エピソード: 160ステップで終了 - rewards: -160
# 1153エピソード: 199ステップで終了 - rewards: -200
# 1154エピソード: 199ステップで終了 - rewards: -200
# 1155エピソード: 129ステップで終了 - rewards: -129
# 1156エピソード: 199ステップで終了 - rewards: -200
# 1157エピソード: 199ステップで終了 - rewards: -200
# 1158エピソード: 199ステップで終了 - rewards: -200
# 1159エピソード: 199ステップで終了 - rewards: -200
# 1160エピソード: 199ステップで終了 - rewards: -200
# 1161エピソード: 199ステップで終了 - rewards: -200
# 1162エピソード: 180ステップで終了 - rewards: -180
# 1163エピソード: 199ステップで終了 - rewards: -200
# 1164エピソード: 166ステップで終了 - rewards: -166
# 1165エピソード: 132ステップで終了 - rewards: -132
# 1166エピソード: 125ステップで終了 - rewards: -125
# 1167エピソード: 199ステップで終了 - rewards: -200
# 1168エピソード: 199ステップで終了 - rewards: -200
# 1169エピソード: 147ステップで終了 - rewards: -147
# 1170エピソード: 170ステップで終了 - rewards: -170
# 1171エピソード: 147ステップで終了 - rewards: -147
# 1172エピソード: 151ステップで終了 - rewards: -151
# 1173エピソード: 174ステップで終了 - rewards: -174
# 1174エピソード: 166ステップで終了 - rewards: -166
# 1175エピソード: 148ステップで終了 - rewards: -148
# 1176エピソード: 199ステップで終了 - rewards: -200
# 1177エピソード: 178ステップで終了 - rewards: -178
# 1178エピソード: 160ステップで終了 - rewards: -160
# 1179エピソード: 199ステップで終了 - rewards: -200
# 1180エピソード: 199ステップで終了 - rewards: -200
# 1181エピソード: 178ステップで終了 - rewards: -178
# 1182エピソード: 167ステップで終了 - rewards: -167
# 1183エピソード: 171ステップで終了 - rewards: -171
# 1184エピソード: 199ステップで終了 - rewards: -200
# 1185エピソード: 199ステップで終了 - rewards: -200
# 1186エピソード: 161ステップで終了 - rewards: -161
# 1187エピソード: 196ステップで終了 - rewards: -196
# 1188エピソード: 199ステップで終了 - rewards: -200
# 1189エピソード: 199ステップで終了 - rewards: -200
# 1190エピソード: 199ステップで終了 - rewards: -200
# 1191エピソード: 199ステップで終了 - rewards: -200
# 1192エピソード: 191ステップで終了 - rewards: -191
# 1193エピソード: 199ステップで終了 - rewards: -200
# 1194エピソード: 168ステップで終了 - rewards: -168
# 1195エピソード: 199ステップで終了 - rewards: -200
# 1196エピソード: 199ステップで終了 - rewards: -200
# 1197エピソード: 167ステップで終了 - rewards: -167
# 1198エピソード: 199ステップで終了 - rewards: -200
# 1199エピソード: 199ステップで終了 - rewards: -200
# 1200エピソード: 179ステップで終了 - rewards: -179
# 1201エピソード: 199ステップで終了 - rewards: -200
# 1202エピソード: 199ステップで終了 - rewards: -200
# 1203エピソード: 172ステップで終了 - rewards: -172
# 1204エピソード: 160ステップで終了 - rewards: -160
# 1205エピソード: 155ステップで終了 - rewards: -155
# 1206エピソード: 181ステップで終了 - rewards: -181
# 1207エピソード: 160ステップで終了 - rewards: -160
# 1208エピソード: 181ステップで終了 - rewards: -181
# 1209エピソード: 169ステップで終了 - rewards: -169
# 1210エピソード: 192ステップで終了 - rewards: -192
# 1211エピソード: 140ステップで終了 - rewards: -140
# 1212エピソード: 187ステップで終了 - rewards: -187
# 10回連続成功
# Execution Time: 367.8449 sec
# 1213エピソード: 122ステップで終了 - rewards: -122
# /Users/ryosuke/grade2/ai_design2/.venv/lib/python3.8/site-packages/JSAnimation/html_writer.py:281: MatplotlibDeprecationWarning:
# The 'clear_temp' parameter of setup() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. If any parameter follows 'clear_temp', they should be passed as keyword, not positionally.
#   super(HTMLWriter, self).setup(fig, outfile, dpi,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-7dfab0e69a06> in <module>
#       1 cartpole_env = Environment()
# ----> 2 cartpole_env.run()
#
# <ipython-input-7-5fbbef3b947d> in run(self)
#      73             # 最終エピソードの場合は動画を保存
#      74             if is_episode_final:
# ---> 75                 save_as_gif(frames)
#      76                 break
#      77             # 10回連続で成功したら、次のエピソードで終わりにする
#
# <ipython-input-3-9ad116eef69b> in save_as_gif(frames)
#      14
#      15     anim.save('MountainCar-v0.mp4')
# ---> 16     display(display_animation(anim, default_mode='loop'))
#
# ~/grade2/ai_design2/.venv/lib/python3.8/site-packages/JSAnimation/IPython_display.py in display_animation(anim, **kwargs)
#      84     """Display the animation with an IPython HTML object"""
#      85     from IPython.display import HTML
# ---> 86     return HTML(anim_to_html(anim, **kwargs))
#      87
#      88
#
# ~/grade2/ai_design2/.venv/lib/python3.8/site-packages/JSAnimation/IPython_display.py in anim_to_html(anim, fps, embed_frames, default_mode)
#      72         #with tempfile.NamedTemporaryFile(suffix='.html') as f:
#      73         with _NameOnlyTemporaryFile(suffix='.html') as f:
# ---> 74             anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                                  embed_frames=embed_frames,
#      76                                                  default_mode=default_mode))
#
# ~/grade2/ai_design2/.venv/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/grade2/ai_design2/.venv/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/grade2/ai_design2/.venv/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     516         # Call run here now that all frame grabbing is done. All temp files
#     517         # are available to be assembled.
# --> 518         self._run()
#     519         MovieWriter.finish(self)  # Will call clean-up
#     520
#
# ~/grade2/ai_design2/.venv/lib/python3.8/site-packages/JSAnimation/html_writer.py in _run(self)
#     321             of.write(JS_INCLUDE)
#     322             of.write(DISPLAY_TEMPLATE.format(id=self.new_id(),
# --> 323                                              Nframes=len(self._temp_names),
#     324                                              fill_frames=fill_frames,
#     325                                              interval=interval,
#
# AttributeError: 'HTMLWriter' object has no attribute '_temp_names'
